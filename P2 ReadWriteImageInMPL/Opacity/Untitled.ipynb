# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

rup = cv2.imread('teto02c01.png')
print(rup.shape)
plt.imshow(rup[:,:,::-1])
plt.show()
# Out:
# (450, 600, 3)

# %%
rup = cv2.imread('teto02c1.png',cv2.IMREAD_UNCHANGED)
plt.imshow(rup[:,:,[2,1,0,3]])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-0206b7ebd6d8> in <module>
#       1 rup = cv2.imread('teto02c1.png',cv2.IMREAD_UNCHANGED)
# ----> 2 plt.imshow(rup[:,:,[2,1,0,3]])
#       3 plt.show()
#
# TypeError: 'NoneType' object is not subscriptable
