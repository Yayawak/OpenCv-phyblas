# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt

rup = cv2.imread('miku02c01.jpg')
print(rup.shape)
# Out:
# (450, 600, 3)

# %%
rup = rup.astype(np.float32)

# %%
print(cv2.IMREAD_COLOR)
# Out:
# 1

# %% [markdown]
# reverse color (bgr)

# %%
rup = cv2.imread('miku02c03.jpg')
plt.imshow(rup)

# %%
plt.imshow(rup[:,:,::-1])

# %%
plt.imshow(rup[:300, :, ::-1])

# %%
rup = cv2.imread('miku02c03.jpg',0)
plt.imshow(rup)
plt.colorbar(pad=0.01)

# %%
plt.imshow(rup, cmap='gray')
plt.colorbar(pad=.01)
plt.show()

# %%
plt.imshow(rup[0:100, 100:300, ],cmap='gray')
plt.show()

# %%
plt.imshow(rup[80:170, 330:440, ], vmin=-0, vmax=255, cmap='gray')
plt.colorbar(pad=0.01)
plt.show()
